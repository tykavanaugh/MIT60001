# %%
'''
Python based hangman game for the MIT open course
'''

import random
import sys


def is_word_guesssed(secret_word,letters_guessed):
    '''
    Returns boolean values to determine if game should continue
    '''
    guess = True
    for i in secret_word:
        if i not in letters_guessed:
            guess = False
    return guess

def get_guessed_word(secret_word,letters_guessed):
    '''
    Prints out of blanked version of secret word for unguessed letters
    '''
    output = []
    for i in secret_word:
            if i in letters_guessed:
                output.append(i)
            else:
                output.append('_')
    output = ''.join(output)
    return(output)
    
def get_available_letters(letters_guessed,alphabet):
    '''
    updates a list of unguessed letters
    '''
    for i in letters_guessed:
        if i in alphabet:
            alphabet = alphabet.replace(i,'')
    return alphabet




WORDLIST_FILENAME = "words.txt"


def load_words():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish. (Function provided by professor)
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist



def choose_word(wordlist):
    """
    wordlist (list): list of words (strings)
    
    Returns a word from wordlist at random (Function provided by professor)
    """
    return random.choice(wordlist)



def hangman(maxWarnings):
    '''
    Hangman game
    '''
    permalphabet = 'abcdefghijklmnopqrstuvwxyz'
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    wordlist = load_words()
    secret_word = choose_word(wordlist)
    letters_guessed = []
    warnings = 0
    while not is_word_guesssed(secret_word,letters_guessed):
        print('You have {} warnings of {}'.format(warnings,maxWarnings))
        print(get_guessed_word(secret_word,letters_guessed))
        print('You have these letters still to choose from:')
        print(get_available_letters(letters_guessed,alphabet))
        print('Type * for hints')
        guess = input('Please type a lowercase letter you would like to guess\n')
        if guess == '*':
            print(hint(letters_guessed,secret_word))
        guess = guess.lower()
        if len(guess) != 1:
            print('\nPlease only type one character\n')
        elif guess not in permalphabet:
            print('\nPlease only type a letter\n')
        elif guess not in letters_guessed:
            print('\nYou guessed {}\n'.format(guess))
            if guess in secret_word:
                print('Good guess!')
            else:
                print('You missed!')
                warnings += 1
                if warnings == maxWarnings:
                    print('Oh no! You lose')
                    print('The word was {}'.format(secret_word))
                    return False
                    menu()
            letters_guessed.append(guess)
        else:
            print('You already guessed {}\n'.format(guess))
        print('------------------------------')
    print('The word is {}\n'.format(secret_word))
    print('Congrats! You win!')
    return (True)
    menu()


def menu(maxWarnings = 5):
    print('Hello! Welcome to hangman. Actual hanging man coming "soon"!' )
    userInput = input('Type "hangman" to play hangman.\nType "options" to change options\nType "random word" to get a random word without starting a game.\nType "exit" to exit\n')
    userInput = userInput.lower()
    if userInput == 'hangman':
        hangman(maxWarnings)
    if userInput == 'options':
        print('Options:\n-------\n1:Warnings before game ends {}'.format(maxWarnings))
        print('Type the number to select option. Typing anything else will return you to the menu')
        option = input('Please type option you would like to change here')
        if option == '1':
            option1 = input('Please choose how many warnings before game ends')
            if type(option1) != int:
                "Input error detected"
            maxWarnings = option1
    if userInput == 'random word':
        wordlist = load_words()
        word = choose_word(wordlist)
        print('')
        print(word)
        print('')
    if userInput == 'exit':
        sys.exit()
    menu(maxWarnings)

# %%
secret_word = 'apocrypha'
letters_guessed = ['e','z','a','p','o','m','f']
def hint(letters_guessed,secret_word):
    all_words = load_words()
    same_length = []
    for word in all_words:
        if len(secret_word) == len(word):
            same_length.append(word)
    wrong_letters = []
    for letter in letters_guessed:
        if letter not in secret_word:
            wrong_letters.append(letter)
    #print(wrong_letters)
    correct_letters = []
    for word in same_length:
        for letter in wrong_letters:
            if letter not in word:
                correct_letters.append(word)
    correct_location = []
    for letter in secret_word:
        for word in correct_letters:
            position = secret_word.index(letter)
            if letter == word[position]:
                correct_location.append(word)
    return(correct_location)

hint(letters_guessed,secret_word)
# Out:
# Loading word list from file...
#    55900 words loaded.
# ['e', 'z', 'm', 'f']
# ['aardvarks',
#  'aardvarks',
#  'aardvarks',
#  'aardvarks',
#  'abandoned',
#  'abandoned',
#  'abandoned',
#  'abasement',
#  'abasement',
#  'abatement',
#  'abatement',
#  'abattoirs',
#  'abattoirs',
#  'abattoirs',
#  'abattoirs',
#  'abdicated',
#  'abdicated',
#  'abdicated',
#  'abdicates',
#  'abdicates',
#  'abdicates',
#  'abdicator',
#  'abdicator',
#  'abdicator',
#  'abdicator',
#  'abdominal',
#  'abdominal',
#  'abdominal',
#  'abducting',
#  'abducting',
#  'abducting',
#  'abducting',
#  'abduction',
#  'abduction',
#  'abduction',
#  'abduction',
#  'abductors',
#  'abductors',
#  'abductors',
#  'abductors',
#  'aberrance',
#  'aberrance',
#  'aberrance',
#  'abeyances',
#  'abeyances',
#  'abeyances',
#  'abhorring',
#  'abhorring',
#  'abhorring',
#  'abhorring',
#  'abhorrers',
#  'abhorrers',
#  'abhorrers',
#  'abhorrent',
#  'abhorrent',
#  'abhorrent',
#  'abidances',
#  'abidances',
#  'abidances',
#  'abidingly',
#  'abidingly',
#  'abidingly',
#  'abidingly',
#  'abilities',
#  'abilities',
#  'abilities',
#  'abjection',
#  'abjection',
#  'abjection',
#  'ablations',
#  'ablations',
#  'ablations',
#  'ablations',
#  'ablatives',
#  'ablatives',
#  'ablatives',
#  'ablutions',
#  'ablutions',
#  'ablutions',
#  'ablutions',
#  'abnegated',
#  'abnegated',
#  'abnegated',
#  'abnegates',
#  'abnegates',
#  'abnegates',
#  'abnegator',
#  'abnegator',
#  'abnegator',
#  'abolished',
#  'abolished',
#  'abolished',
#  'abolishes',
#  'abolishes',
#  'abolishes',
#  'abolition',
#  'abolition',
#  'abolition',
#  'abolition',
#  'abominate',
#  'abominate',
#  'aborigine',
#  'aborigine',
#  'aborigine',
#  'abortions',
#  'abortions',
#  'abortions',
#  'abortions',
#  'abounding',
#  'abounding',
#  'abounding',
#  'abounding',
#  'abrasions',
#  'abrasions',
#  'abrasions',
#  'abrasions',
#  'abrasives',
#  'abrasives',
#  'abrasives',
#  'abridging',
#  'abridging',
#  'abridging',
#  'abridging',
#  'abridgers',
#  'abridgers',
#  'abridgers',
#  'abrogated',
#  'abrogated',
#  'abrogated',
#  'abrogates',
#  'abrogates',
#  'abrogates',
#  'abscessed',
#  'abscessed',
#  'abscessed',
#  'abscesses',
#  'abscesses',
#  'abscesses',
#  'abscising',
#  'abscising',
#  'abscising',
#  'abscising',
#  'abscissas',
#  'abscissas',
#  'abscissas',
#  'abscissas',
#  'absconded',
#  'absconded',
#  'absconded',
#  'absenting',
#  'absenting',
#  'absenting',
#  'absentees',
#  'absentees',
#  'absentees',
#  'absinthes',
#  'absinthes',
#  'absinthes',
#  'absolutes',
#  'absolutes',
#  'absolutes',
#  'absolving',
#  'absolving',
#  'absolving',
#  'absolving',
#  'absolvers',
#  'absolvers',
#  'absolvers',
#  'absorbing',
#  'absorbing',
#  'absorbing',
#  'absorbing',
#  'absorbers',
#  'absorbers',
#  'absorbers',
#  'absorbent',
#  'absorbent',
#  'absorbent',
#  'abstained',
#  'abstained',
#  'abstained',
#  'abstinent',
#  'abstinent',
#  'abstinent',
#  'abstracts',
#  'abstracts',
#  'abstracts',
#  'abstracts',
#  'absurdity',
#  'absurdity',
#  'absurdity',
#  'absurdity',
#  'abundance',
#  'abundance',
#  'abundance',
#  'abusively',
#  'abusively',
#  'abusively',
#  'abutments',
#  'abutments',
#  'abysmally',
#  'abysmally',
#  'abysmally',
#  'academies',
#  'academies',
#  'academics',
#  'academics',
#  'accedence',
#  'accedence',
#  'accedence',
#  'accenting',
#  'accenting',
#  'accenting',
#  'accentual',
#  'accentual',
#  'accentual',
#  'accepting',
#  'accepting',
#  'accepting',
#  'acceptors',
#  'acceptors',
#  'acceptors',
#  'accessing',
#  'accessing',
#  'accessing',
#  'accession',
#  'accession',
#  'accession',
#  'accessory',
#  'accessory',
#  'accessory',
#  'accidence',
#  'accidence',
#  'accidence',
#  'accidents',
#  'accidents',
#  'accidents',
#  'acclaimed',
#  'acclaimed',
#  'acclimate',
#  'acclimate',
#  'acclivity',
#  'acclivity',
#  'acclivity',
#  'acclivity',
#  'accolades',
#  'accolades',
#  'accolades',
#  'accompany',
#  'accompany',
#  'accompany',
#  'accomplis',
#  'accomplis',
#  'accomplis',
#  'according',
#  'according',
#  'according',
#  'according',
#  'accordion',
#  'accordion',
#  'accordion',
#  'accordion',
#  'accosting',
#  'accosting',
#  'accosting',
#  'accosting',
#  'accounted',
#  'accounted',
#  'accounted',
#  'accouters',
#  'accouters',
#  'accouters',
#  'accredits',
#  'accredits',
#  'accredits',
#  'accretion',
#  'accretion',
#  'accretion',
#  'accruable',
#  'accruable',
#  'accruable',
#  'accustoms',
#  'accustoms',
#  'accustoms',
#  'acerbated',
#  'acerbated',
#  'acerbated',
#  'acerbates',
#  'acerbates',
#  'acerbates',
#  'acetylene',
#  'acetylene',
#  'acetylene',
#  'achieving',
#  'achieving',
#  'achieving',
#  'achievers',
#  'achievers',
#  'achievers',
#  'aciculate',
#  'aciculate',
#  'aciculate',
#  'acidities',
#  'acidities',
#  'acidities',
#  'acidified',
#  'acidified',
#  'acidifier',
#  'acidifier',
#  'acidifies',
#  'acidifies',
#  'acidulate',
#  'acidulate',
#  'acidulate',
#  'acidulous',
#  'acidulous',
#  'acidulous',
#  'acidulous',
#  'acoustics',
#  'acoustics',
#  'acoustics',
#  'acoustics',
#  'acquaints',
#  'acquaints',
#  'acquaints',
#  'acquaints',
#  'acquiesce',
#  'acquiesce',
#  'acquiesce',
#  'acquiring',
#  'acquiring',
#  'acquiring',
#  'acquiring',
#  'acquirers',
#  'acquirers',
#  'acquirers',
#  'acquitted',
#  'acquitted',
#  'acquitted',
#  'acquittor',
#  'acquittor',
#  'acquittor',
#  'acquittor',
#  'acquittal',
#  'acquittal',
#  'acquittal',
#  'acquittal',
#  'acrobatic',
#  'acrobatic',
#  'acrobatic',
#  'acrobatic',
#  'acronymic',
#  'acronymic',
#  'acronymic',
#  'acropolis',
#  'acropolis',
#  'acropolis',
#  'acropolis',
#  'acrostics',
#  'acrostics',
#  'acrostics',
#  'acrostics',
#  'actinisms',
#  'actinisms',
#  'actinisms',
#  'actinides',
#  'actinides',
#  'actinides',
#  'actiniums',
#  'actiniums',
#  'actiniums',
#  'activists',
#  'activists',
#  'activists',
#  'activists',
#  'activisms',
#  'activisms',
#  'activisms',
#  'activated',
#  'activated',
#  'activated',
#  'activates',
#  'activates',
#  'activates',
#  'activator',
#  'activator',
#  'activator',
#  'activator',
#  'actresses',
#  'actresses',
#  'actresses',
#  'actuality',
#  'actuality',
#  'actuality',
#  'actuality',
#  'actualize',
#  'actualize',
#  'actuaries',
#  'actuaries',
#  'actuaries',
#  'actuarial',
#  'actuarial',
#  'actuarial',
#  'actuarial',
#  'actuating',
#  'actuating',
#  'actuating',
#  'actuating',
#  'actuation',
#  'actuation',
#  'actuation',
#  'actuation',
#  'actuators',
#  'actuators',
#  'actuators',
#  'actuators',
#  'acuteness',
#  'acuteness',
#  'acuteness',
#  'adamantly',
#  'adamantly',
#  'adamantly',
#  'adaptable',
#  'adaptable',
#  'adaptable',
#  'addicting',
#  'addicting',
#  'addicting',
#  'addicting',
#  'addiction',
#  'addiction',
#  'addiction',
#  'addiction',
#  'addictive',
#  'addictive',
#  'addictive',
#  'additions',
#  'additions',
#  'additions',
#  'additions',
#  'additives',
#  'additives',
#  'additives',
#  'addressed',
#  'addressed',
#  'addressed',
#  'addresser',
#  'addresser',
#  'addresser',
#  'addresses',
#  'addresses',
#  'addresses',
#  'addressee',
#  'addressee',
#  'addressee',
#  'adducting',
#  'adducting',
#  'adducting',
#  'adducting',
#  'adduction',
#  'adduction',
#  'adduction',
#  'adduction',
#  'adductive',
#  'adductive',
#  'adductive',
#  'adductors',
#  'adductors',
#  'adductors',
#  'adductors',
#  'adenoidal',
#  'adenoidal',
#  'adenoidal',
#  'adenosine',
#  'adenosine',
#  'adenosine',
#  'adeptness',
#  'adeptness',
#  'adeptness',
#  'adherence',
#  'adherence',
#  'adherence',
#  'adherents',
#  'adherents',
#  'adherents',
#  'adhesions',
#  'adhesions',
#  'adhesions',
#  'adhesives',
#  'adhesives',
#  'adhesives',
#  'adiabatic',
#  'adiabatic',
#  'adiabatic',
#  'adiabatic',
#  'adiposity',
#  'adiposity',
#  'adiposity',
#  'adiposity',
#  'adjacency',
#  'adjacency',
#  'adjacency',
#  'adjective',
#  'adjective',
#  'adjective',
#  'adjoining',
#  'adjoining',
#  'adjoining',
#  'adjoining',
#  'adjourned',
#  'adjourned',
#  'adjourned',
#  'adjudging',
#  'adjudging',
#  'adjudging',
#  'adjudging',
#  'adjusting',
#  'adjusting',
#  'adjusting',
#  'adjusting',
#  'adjusters',
#  'adjusters',
#  'adjusters',
#  'adjutants',
#  'adjutants',
#  'adjutants',
#  'adjutants',
#  'admirably',
#  'admirably',
#  'admirably',
#  'admirable',
#  'admirable',
#  'admiralty',
#  'admiralty',
#  'admiralty',
#  'admission',
#  'admission',
#  'admission',
#  'admissive',
#  'admissive',
#  'admitting',
#  'admitting',
#  'admitting',
#  'admixture',
#  'admixture',
#  'adoptions',
#  'adoptions',
#  'adoptions',
#  'adoptions',
#  'adoration',
#  'adoration',
#  'adoration',
#  'adoration',
#  'adoringly',
#  'adoringly',
#  'adoringly',
#  'adoringly',
#  'adornment',
#  'adornment',
#  'adrenalin',
#  'adrenalin',
#  'adrenalin',
#  'adsorbing',
#  'adsorbing',
#  'adsorbing',
#  'adsorbing',
#  'adsorbent',
#  'adsorbent',
#  'adsorbent',
#  'adulating',
#  'adulating',
#  'adulating',
#  'adulating',
#  'adulation',
#  'adulation',
#  'adulation',
#  'adulation',
#  'adulators',
#  'adulators',
#  'adulators',
#  'adulators',
#  'adulatory',
#  'adulatory',
#  'adulatory',
#  'adulatory',
#  'adulterer',
#  'adulterer',
#  'adulterer',
#  'adulthood',
#  'adulthood',
#  'adulthood',
#  'adulthood',
#  'adumbrate',
#  'adumbrate',
#  'advancing',
#  'advancing',
#  'advancing',
#  'advancing',
#  'advancers',
#  'advancers',
#  'advancers',
#  'advantage',
#  'advantage',
#  'advantage',
#  'adventist',
#  'adventist',
#  'adventist',
#  'adventure',
#  'adventure',
#  'adventure',
#  'adverbial',
#  'adverbial',
#  'adverbial',
#  'adversity',
#  'adversity',
#  'adversity',
#  'adversary',
#  'adversary',
#  'adversary',
#  'adversely',
#  'adversely',
#  'adversely',
#  'adverting',
#  'adverting',
#  'adverting',
#  'advertise',
#  'advertise',
#  'advertise',
#  'advisably',
#  'advisably',
#  'advisably',
#  'advisably',
#  'advisable',
#  'advisable',
#  'advisable',
#  'advisedly',
#  'advisedly',
#  'advisedly',
#  'advocated',
#  'advocated',
#  'advocated',
#  'advocates',
#  'advocates',
#  'advocates',
#  'advocator',
#  'advocator',
#  'advocator',
#  'advocator',
#  'aerations',
#  'aerations',
#  'aerations',
#  'aerialist',
#  'aerialist',
#  'aerialist',
#  'aeronauts',
#  'aeronauts',
#  'aeronauts',
#  'aeropause',
#  'aeropause',
#  'aeropause',
#  'aerospace',
#  'aerospace',
#  'aerospace',
#  'aerostats',
#  'aerostats',
#  'aerostats',
#  'aesthetes',
#  'aesthetes',
#  'aesthetes',
#  'aesthetic',
#  'aesthetic',
#  'aesthetic',
#  'aestivate',
#  'aestivate',
#  'aestivate',
#  'affection',
#  'affection',
#  'affective',
#  'affective',
#  'affecting',
#  'affecting',
#  'affiances',
#  'affiances',
#  'affianced',
#  'affianced',
#  'affidavit',
#  'affidavit',
#  'affidavit',
#  'affiliate',
#  'affiliate',
#  'affirming',
#  'affirming',
#  'affirmant',
#  'affirmant',
#  'afflation',
#  'afflation',
#  'afflation',
#  'afflicted',
#  'afflicted',
#  'affluence',
#  'affluence',
#  'affluents',
#  'affluents',
#  'affording',
#  'affording',
#  'affording',
#  'affronted',
#  'affronted',
#  'aforesaid',
#  'aforesaid',
#  'afrikaans',
#  'afrikaans',
#  'afrikaans',
#  'aftercare',
#  'aftercare',
#  'afterdeck',
#  'afterdeck',
#  'afterglow',
#  'afterglow',
#  'afterlife',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'afternoon',
#  'afterward',
#  'afterward',
#  'ageratums',
#  'ageratums',
#  'aggravate',
#  'aggravate',
#  'aggravate',
#  'aggregate',
#  'aggregate',
#  'aggregate',
#  'aggressed',
#  'aggressed',
#  'aggressed',
#  'aggresses',
#  'aggresses',
#  'aggresses',
#  'aggressor',
#  'aggressor',
#  'aggressor',
#  'aggrieved',
#  'aggrieved',
#  'aggrieved',
#  'aggrieves',
#  'aggrieves',
#  'aggrieves',
#  'agilities',
#  'agilities',
#  'agilities',
#  'agitating',
#  'agitating',
#  'agitating',
#  'agitating',
#  'agitation',
#  'agitation',
#  'agitation',
#  'agitation',
#  'agitators',
#  'agitators',
#  'agitators',
#  'agitators',
#  'agnostics',
#  'agnostics',
#  'agnostics',
#  'agnostics',
#  'agonizing',
#  'agonizing',
#  'agonizing',
#  'agrarians',
#  'agrarians',
#  'agrarians',
#  'agrarians',
#  'agreeably',
#  'agreeably',
#  'agreeably',
#  'agreement',
#  'agreement',
#  'agreeable',
#  'agreeable',
#  'agreeable',
#  'agronomic',
#  'agronomic',
#  'agronomic',
#  'aigrettes',
#  'aigrettes',
#  'aigrettes',
#  'ailanthus',
#  'ailanthus',
#  'ailanthus',
#  'ailanthus',
#  'aimlessly',
#  'aimlessly',
#  'airdromes',
#  'airdromes',
#  'airedales',
#  'airedales',
#  'airedales',
#  'airfields',
#  'airfields',
#  'airlifted',
#  'airlifted',
#  'airliners',
#  'airliners',
#  'airliners',
#  'airmailed',
#  'airmailed',
#  'airplanes',
#  'airplanes',
#  'airplanes',
#  'airspaces',
#  'airspaces',
#  'airspaces',
#  'airstrips',
#  'airstrips',
#  'airstrips',
#  'airstrips',
#  'airworthy',
#  'airworthy',
#  'airworthy',
#  'airworthy',
#  'alabaster',
#  'alabaster',
#  'alabaster',
#  'alarmists',
#  'alarmists',
#  'alarmists',
#  'albacores',
#  'albacores',
#  'albacores',
#  'albatross',
#  'albatross',
#  'albatross',
#  'albatross',
#  'alchemies',
#  'alchemies',
#  'alchemist',
#  'alchemist',
#  'alcoholic',
#  'alcoholic',
#  'alcoholic',
#  'alcoholic',
#  'aldehydes',
#  'aldehydes',
#  'aldehydes',
#  'alehouses',
#  'alehouses',
#  'alehouses',
#  'alertness',
#  'alertness',
#  'alertness',
#  'algebraic',
#  'algebraic',
#  'algebraic',
#  'algerians',
#  'algerians',
#  'algerians',
#  'algorithm',
#  'algorithm',
#  'algorithm',
#  'alienists',
#  'alienists',
#  'alienists',
#  'alienable',
#  'alienable',
#  'alienable',
#  'alienated',
#  'alienated',
#  'alienated',
#  'alienates',
#  'alienates',
#  'alienates',
#  'alienator',
#  'alienator',
#  'alienator',
#  'alighting',
#  'alighting',
#  'alighting',
#  'alighting',
#  'alignment',
#  'alignment',
#  'alikeness',
#  'alikeness',
#  'alikeness',
#  'alimonies',
#  'alimonies',
#  'aliphatic',
#  'aliphatic',
#  'aliphatic',
#  'aliphatic',
#  'alkalized',
#  'alkalized',
#  'alkalizes',
#  'alkalizes',
#  'alkaloids',
#  'alkaloids',
#  'alkaloids',
#  'alkaloids',
#  'alkaloses',
#  'alkaloses',
#  'alkaloses',
#  'alkalosis',
#  'alkalosis',
#  'alkalosis',
#  'alkalosis',
#  'allantois',
#  'allantois',
#  'allantois',
#  'allantois',
#  'allayment',
#  'allayment',
#  'allegedly',
#  'allegedly',
#  'allegedly',
#  'allegoric',
#  'allegoric',
#  'allegoric',
#  'alleluias',
#  'alleluias',
#  'alleluias',
#  'allemande',
#  'allemande',
#  'allergies',
#  'allergies',
#  'allergies',
#  'allergist',
#  'allergist',
#  'allergist',
#  'allergens',
#  'allergens',
#  'allergens',
#  'alleviate',
#  'alleviate',
#  'alleviate',
#  'alleyways',
#  'alleyways',
#  'alleyways',
#  'alliances',
#  'alliances',
#  'alliances',
#  'alligator',
#  'alligator',
#  'alligator',
#  'alligator',
#  'allocable',
#  'allocable',
#  'allocable',
#  'allocated',
#  'allocated',
#  'allocated',
#  'allocates',
#  'allocates',
#  'allocates',
#  'allomorph',
#  'allomorph',
#  'allomorph',
#  'allopathy',
#  'allopathy',
#  'allopathy',
#  'allopathy',
#  'allophone',
#  'allophone',
#  'allophone',
#  'allotment',
#  'allotment',
#  'allotrope',
#  'allotrope',
#  'allotrope',
#  'allotropy',
#  'allotropy',
#  'allotropy',
#  'allotropy',
#  'allotting',
#  'allotting',
#  'allotting',
#  'allotting',
#  'allowably',
#  'allowably',
#  'allowably',
#  'allowably',
#  'allowable',
#  'allowable',
#  'allowable',
#  'allowance',
#  'allowance',
#  'allowance',
#  'allspices',
#  'allspices',
#  'allspices',
#  'allusions',
#  'allusions',
#  'allusions',
#  'allusions',
#  'alluviums',
#  'alluviums',
#  'alluviums',
#  'almsgiver',
#  'almsgiver',
#  ...]

# %%
secret_word[1]
# Out:
# 'p'

# %%
secret_word.index('a')
# Out:
# 0

# %%
menu()
# Out:
# Hello! Welcome to hangman. Actual hanging man coming "soon"!
# Type "hangman" to play hangman.
# Type "options" to change options
# Type "random word" to get a random word without starting a game.
# Type "exit" to exit
# hangman
# Loading word list from file...
#    55900 words loaded.
# You have 0 warnings of 5
# ______
# You have these letters still to choose from:
# abcdefghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# *
# []
#
# Please only type a letter
#
# ------------------------------
# You have 0 warnings of 5
# ______
# You have these letters still to choose from:
# abcdefghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# a
#
# You guessed a
#
# You missed!
# ------------------------------
# You have 1 warnings of 5
# ______
# You have these letters still to choose from:
# bcdefghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# e
#
# You guessed e
#
# Good guess!
# ------------------------------
# You have 1 warnings of 5
# _e____
# You have these letters still to choose from:
# bcdfghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# *
# ['beckon', 'become', 'bedbug', 'bedded', 'bedeck', 'bedews', 'beefed', 'beeped', 'beeper', 'beetle', 'beeves', 'befell', 'befits', 'befogs', 'before', 'befoul', 'begets', 'begged', 'begins', 'begird', 'begirt', 'beheld', 'behest', 'behind', 'behold', 'beiges', 'beings', 'beirut', 'belfry', 'belied', 'belies', 'belief', 'belize', 'belled', 'belles', 'bellow', 'belong', 'belows', 'belted', 'bemire', 'bemuse', 'bender', 'benign', 'benumb', 'benzol', 'berber', 'bereft', 'berets', 'berlin', 'berths', 'beryls', 'beseem', 'besets', 'beside', 'besots', 'bested', 'bestir', 'bestow', 'betels', 'betide', 'betook', 'bettor', 'better', 'bevels', 'bevies', 'beyond', 'bezels', 'bibles', 'biceps', 'bicker', 'bidder', 'bidden', 'bidets', 'bigger', 'bikers', 'bilged', 'bilges', 'bilked', 'billed', 'billet', 'binder', 'binges', 'biomes', 'bipeds', 'birdie', 'bisect', 'bisque', 'biters', 'bitten', 'bitter', 'bleeds', 'bleeps', 'blench', 'blends', 'blithe', 'blokes', 'blonde', 'blouse', 'blower', 'bluest', 'bluets', 'bobbed', 'bobble', 'bodies', 'bodice', 'bogeys', 'bogged', 'boggle', 'bogies', 'boiled', 'boiler', 'bolder', 'bolero', 'bolted', 'bombed', 'bomber', 'bonded', 'boners', 'bonged', 'bonier', 'bonnet', 'boodle', 'booked', 'booker', 'bookie', 'boomed', 'booted', 'bootee', 'boozed', 'boozes', 'bopped', 'border', 'borers', 'borneo', 'bossed', 'bosses', 'bother', 'bottle', 'bounce', 'bourse', 'bovine', 'bowels', 'bowers', 'bowies', 'bowled', 'bowler', 'bowleg', 'boxers', 'boxier', 'breech', 'breeds', 'breeze', 'breezy', 'breton', 'brevet', 'brewed', 'brewer', 'bribed', 'bribes', 'brides', 'bridle', 'bridge', 'briefs', 'briers', 'brines', 'brogue', 'broker', 'broken', 'bronze', 'browse', 'bruise', 'brumes', 'brunei', 'brunet', 'brutes', 'bubble', 'buboes', 'bucked', 'buckle', 'bucket', 'budded', 'budder', 'budged', 'budges', 'budget', 'budgie', 'buenos', 'buffed', 'buffer', 'buffet', 'bugged', 'bugled', 'bugler', 'bugles', 'bulged', 'bulges', 'bulked', 'bulled', 'bullet', 'bumble', 'bummed', 'bumped', 'bumper', 'bundle', 'bunged', 'bungle', 'bunked', 'bunker', 'bunsen', 'bunted', 'buoyed', 'burble', 'burden', 'burger', 'burgle', 'buried', 'buries', 'burled', 'burned', 'burner', 'burped', 'burred', 'bushed', 'bushes', 'bushel', 'busied', 'busier', 'busies', 'bussed', 'busses', 'busted', 'buster', 'bustle', 'butler', 'butted', 'buttes', 'butter', 'buyers', 'buzzed', 'buzzer', 'buzzes', 'bygone', 'ceding', 'celery', 'celled', 'cellos', 'celtic', 'cement', 'censer', 'censor', 'census', 'center', 'cerise', 'cerium', 'cermet', 'cervix', 'cesium', 'ceylon', 'checks', 'cheeks', 'cheeky', 'cheeps', 'cheers', 'cheery', 'cheese', 'cheesy', 'chemin', 'cherry', 'cherub', 'chests', 'chewed', 'chicle', 'chided', 'chides', 'chiefs', 'chimed', 'chimes', 'chines', 'chisel', 'chives', 'choice', 'choked', 'choker', 'chokes', 'choler', 'choose', 'chores', 'chosen', 'chrome', 'chutes', 'ciders', 'cinder', 'cipher', 'circle', 'cirque', 'cities', 'civets', 'clefts', 'clench', 'clergy', 'cleric', 'clerks', 'clever', 'cliche', 'client', 'climes', 'clines', 'clique', 'cloche', 'cloned', 'clones', 'closed', 'closer', 'closes', 'closet', 'clothe', 'clover', 'cloves', 'cloven', 'cloyed', 'cobble', 'cobweb', 'cocked', 'cocker', 'cockle', 'coddle', 'codger', 'coerce', 'coffer', 'coffee', 'cogent', 'cohere', 'coifed', 'coiled', 'coined', 'colder', 'coleus', 'collie', 'combed', 'comely', 'comedy', 'comedo', 'comers', 'comets', 'compel', 'confer', 'conger', 'conies', 'conked', 'conned', 'convex', 'convey', 'cooked', 'cooker', 'cookie', 'cooled', 'cooler', 'coolie', 'cooped', 'cooper', 'cootie', 'copied', 'copier', 'copies', 'copped', 'copper', 'copses', 'copter', 'corbel', 'corded', 'corers', 'corked', 'corker', 'corned', 'corner', 'cornet', 'corpse', 'corset', 'cortex', 'cosine', 'cosset', 'cotter', 'coulee', 'coupes', 'couple', 'course', 'covens', 'covers', 'covert', 'covets', 'coveys', 'cowers', 'cowled', 'coyest', 'coyote', 'cozens', 'cozier', 'creche', 'credit', 'credos', ...
#
# Please only type a letter
#
# ------------------------------
# You have 1 warnings of 5
# _e____
# You have these letters still to choose from:
# bcdfghijklmnopqrstuvwxyz
# Type * for hints
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-758d11670cd5> in <module>()
# ----> 1 menu()
#
# <ipython-input-2-cfabd22bafdd> in menu(maxWarnings)
#     125     userInput = userInput.lower()
#     126     if userInput == 'hangman':
# --> 127         hangman(maxWarnings)
#     128     if userInput == 'options':
#     129         print('Options:\n-------\n1:Warnings before game ends {}'.format(maxWarnings))
#
# <ipython-input-2-cfabd22bafdd> in hangman(maxWarnings)
#      90         print(get_available_letters(letters_guessed,alphabet))
#      91         print('Type * for hints')
# ---> 92         guess = input('Please type a lowercase letter you would like to guess\n')
#      93         if guess == '*':
#      94             print(hint(letters_guessed,wordlist,secret_word))
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
menu()
# Out:
# Hello! Welcome to hangman. Actual hanging man coming "soon"!
# Type "hangman" to play hangman.
# Type "options" to change options
# Type "random word" to get a random word without starting a game.
# Type "exit" to exit
# hangman
# Loading word list from file...
#    55900 words loaded.
# You have 0 warnings of 5
# ______
# You have these letters still to choose from:
# abcdefghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# e
#
# You guessed e
#
# You missed!
# ------------------------------
# You have 1 warnings of 5
# ______
# You have these letters still to choose from:
# abcdfghijklmnopqrstuvwxyz
# Type * for hints
# Please type a lowercase letter you would like to guess
# *
# Loading word list from file...
#    55900 words loaded.
# []
#
# Please only type a letter
#
# ------------------------------
# You have 1 warnings of 5
# ______
# You have these letters still to choose from:
# abcdfghijklmnopqrstuvwxyz
# Type * for hints
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-758d11670cd5> in <module>()
# ----> 1 menu()
#
# <ipython-input-4-4426a3032c14> in menu(maxWarnings)
#     125     userInput = userInput.lower()
#     126     if userInput == 'hangman':
# --> 127         hangman(maxWarnings)
#     128     if userInput == 'options':
#     129         print('Options:\n-------\n1:Warnings before game ends {}'.format(maxWarnings))
#
# <ipython-input-4-4426a3032c14> in hangman(maxWarnings)
#      90         print(get_available_letters(letters_guessed,alphabet))
#      91         print('Type * for hints')
# ---> 92         guess = input('Please type a lowercase letter you would like to guess\n')
#      93         if guess == '*':
#      94             print(hint(letters_guessed,secret_word))
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
